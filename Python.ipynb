# %%
print("Hello World")

# %%
name = "Flavio"
print(name)

# %%
name = "Roger"
type(name) == str # True

# %%
name = "Gundu Bhuvan"
isinstance(name, str) # True

# %%
age = 1
type(age) == int # True

# %%
fraction = 0.1
intFraction = int(fraction)
print(intFraction) # 0

# %%
age = 8
anotherVariable = age 
print(anotherVariable)

# %%
a = 1 + 1 # 2
b = 2 - 1 # 1
c = 2 * 2 # 4
d = 4 / 2 # 2
e = 4 % 3 # 1
f = 4 ** 2 # 16
g = 4 // 2 # 2

print(a, b, c, d, e, f, g, sep='\n')

# %%
print(-4) #-4

# %%
print("Roger " + "is a good dog")

# %%
age = 8
age += 1
print(age)

number = 10
number -= 2
print(number)

num = 6
num *= 99
print(num)

# %%
a = 1
b = 2
equals = a == b # False
not_equal = a != b # True
greater = a > b # False
less = a < b # True
greater_equal = a >= b # False
less_equal = a <= b # True

print(equals, not_equal, greater, less, greater_equal, less_equal, sep='\n')

# %%
condition1 = True
condition2 = False

not condition1 # False
print(condition1 and condition2) # False
print(condition1 or condition2) # True

# %%
print(0 or 1) ### 1
print(False or 'hey') ### 'hey'
print('hi' or 'hey') ### 'hi'
print([] or False) ### False
print(False or []) ### []

# %%
print(0 and 1) ### 0
print(1 and 0) ### 0
print(False and 'hey') ### False
print('hi' and 'hey') ### 'hey'
print([] and False) ### []
print(False and []) ### False

# %%
def demonstrate_bitwise_operators():
    # Define two integers
    a = 10  # Binary: 1010
    b = 4   # Binary: 0100

    print(f"Initial values:")
    print(f"a = {a} (Binary: {bin(a)})")
    print(f"b = {b} (Binary: {bin(b)})")
    print("-" * 40)

    # Bitwise AND (&)
    # Sets each bit to 1 if both bits are 1
    # 1010
    # 0100
    # ----
    # 0000 -> 0
    bitwise_and = a & b
    print(f"a & b  (AND)        : {bitwise_and} \t(Binary: {bin(bitwise_and)})")

    # Bitwise OR (|)
    # Sets each bit to 1 if one of two bits is 1
    # 1010
    # 0100
    # ----
    # 1110 -> 14
    bitwise_or = a | b
    print(f"a | b  (OR)         : {bitwise_or} \t(Binary: {bin(bitwise_or)})")

    # Bitwise XOR (^)
    # Sets each bit to 1 if only one of two bits is 1
    # 1010
    # 0100
    # ----
    # 1110 -> 14
    bitwise_xor = a ^ b
    print(f"a ^ b  (XOR)        : {bitwise_xor} \t(Binary: {bin(bitwise_xor)})")

    # Bitwise NOT (~)
    # Inverts all the bits
    # Returns one's complement of the number -> -(x + 1)
    # ~10 = -11
    bitwise_not_a = ~a
    print(f"~a     (NOT)        : {bitwise_not_a} \t(Binary: {bin(bitwise_not_a)})")

    # Bitwise Left Shift (<<)
    # Shift left by pushing zeros in from the right and let the leftmost bits fall off
    # 10 (1010) << 2 -> 101000 -> 40
    left_shift = a << 2
    print(f"a << 2 (Left Shift) : {left_shift} \t(Binary: {bin(left_shift)})")

    # Bitwise Right Shift (>>)
    # Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off
    # 10 (1010) >> 1 -> 0101 -> 5
    right_shift = a >> 1
    print(f"a >> 1 (Right Shift): {right_shift} \t(Binary: {bin(right_shift)})")

if __name__ == "__main__":
    demonstrate_bitwise_operators()
# Out:
# Initial values:
# a = 10 (Binary: 0b1010)
# b = 4 (Binary: 0b100)
# ----------------------------------------
# a & b  (AND)        : 0 	(Binary: 0b0)
# a | b  (OR)         : 14 	(Binary: 0b1110)
# a ^ b  (XOR)        : 14 	(Binary: 0b1110)
# ~a     (NOT)        : -11 	(Binary: -0b1011)
# a << 2 (Left Shift) : 40 	(Binary: 0b101000)
# a >> 1 (Right Shift): 5 	(Binary: 0b101)
