# %%
print("Hello World")

# %%
name = "Flavio"
print(name)

# %%
name = "Roger"
type(name) == str # True

# %%
name = "Gundu Bhuvan"
isinstance(name, str) # True

# %%
age = 1
type(age) == int # True

# %%
fraction = 0.1
intFraction = int(fraction)
print(intFraction) # 0

# %%
age = 8
anotherVariable = age 
print(anotherVariable)

# %%
a = 1 + 1 # 2
b = 2 - 1 # 1
c = 2 * 2 # 4
d = 4 / 2 # 2
e = 4 % 3 # 1
f = 4 ** 2 # 16
g = 4 // 2 # 2

print(a, b, c, d, e, f, g, sep='\n')
